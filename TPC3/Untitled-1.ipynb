# %%
#TPC3 : Aplicação para manipulação de listas de inteiros 
import random
import os 

#[1] Criar Lista
def criaLista() :
    lista = []
    numeroElem = random.randrange(1, 100) 
    for elem in range(numeroElem) :
        lista.append(random.randrange(1, 100))
        #print(elem)
    print("O número de elementos é ", numeroElem)
    return lista

#[2] Ler Lista
def leLista():
    lista = []
    nelem = int(input("Número de elementos da lista: "))
    num = 1
    while num <= nelem :
        lista.append(int(input("Introduza o elemento " + str(num) + ":")))
        num = num + 1
    return lista

#[3] Soma 
def somaLista(lista): 
    soma = 0
    for n in lista :
        soma = soma + n
    return soma 
#[4] Média
def mediaLista(lista):
    soma = 0
    for n in lista :
        soma = soma + n
    return soma/len(lista)

#[5] Maior
def maiorLista(lista):
    maior = lista[0]
    for n in lista[1 :] :
        if n > maior :
            maior = n
    return maior

#[6] Menor
def menorLista(lista):
    menor = lista[0]
    for n in lista[1 :] :
        if n < menor :
            menor = n
    return menor
#[7] EstaOrdenada por ordem crescente
def estaOrdenadaC(lista):
    n = 0
    elemMenor = lista[0]
    while n < len(lista) :
        elem = lista[n]
        n = n + 1
        if elem > elemMenor :
            mensagem = str("Sim")
            elemMenor = elem
        else :
            mensagem = str("Não")
    return mensagem 

#[8] EstaOrdenada por ordem decrescente
def estaOrdenadaD(lista):
    n = 0
    elemMaior = lista[0]
    while n > len(lista) :
        elem = lista[n]
        n = n + 1
        if elem < elemMaior :
            mensagem = str("Sim")
            elemMaior = elem
        else :
            mensagem = str("Não")
    return mensagem 
#[9] Procura um elemento
def unicos(lista, elem):
    res = 0
    if elem in lista :
        res = lista.index(elem)
    else :
        print("Elemento não encontrado")
    return res



resp = 11 
lista = criaLista()  
while resp != 0 :
    print("""(1) Criar Lista)
(2) Ler Lista
(3) Soma
(4) Média
(5) Maior
(6) Menor
(7) EstaOrdenada por ordem crescente
(8) EstaOrdenada por ordem decrescente
(9) Procura um elemento
(0) Sair""")
        
    resp = int(input("Introduza a opção"))

    if resp == 1 :
        os.system("cls")
        lista = criaLista()
        print("A lista gerada foi" , lista) 
    elif resp == 2 :
        os.system("cls")
        lista = leLista()
        print("A lista criada foi" , lista)
    elif resp == 3 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        soma = somaLista(lista)
        print("A soma da lista é ", soma)
    elif resp == 4 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        media = mediaLista(lista)
        print("A média é ", media)
    elif resp == 5 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        maior = maiorLista(lista)
        print("O maior da lista é ", maior)
    elif resp == 6 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        menor = menorLista(lista)
        print("O menor da lista é ", menor)
    elif resp == 7 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        crescente = estaOrdenadaC(lista)
        if crescente == True :
            print("A lista está ordenada por ordem crescente")
        else :
            print("A lista não está ordenada por ordem crescente")
    elif resp == 8 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        decrescente = estaOrdenadaD(lista)
        if decrescente == True :
            print("A lista está ordenada por ordem decrescente")
        else :
            print("A lista não está ordenada por ordem decrescente")
    elif resp == 9 :
        os.system("cls")
        print("A lista é a seguinte", lista)
        valor = False
        N = int(input("Qual o elemento que procura?"))
        for n in lista :
            if N == n :
                valor = True
            if valor == True :
                print("O elemento está na lista")
            else :
                print("O valor não está na lista")
    elif resp == 0 :
        print("A lista é a seguinte", lista) 
         
    else :
        print("A opção selecionada não é válida")
# Out:
# O número de elementos é  47
# (1) Criar Lista)
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) EstaOrdenada por ordem crescente
# (8) EstaOrdenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# O número de elementos é  57
# A lista gerada foi [93, 7, 5, 5, 40, 47, 15, 97, 8, 65, 80, 82, 5, 86, 20, 16, 8, 19, 51, 22, 41, 33, 61, 84, 42, 17, 9, 62, 59, 93, 85, 31, 10, 74, 95, 37, 90, 18, 40, 7, 41, 31, 48, 56, 70, 83, 79, 13, 72, 46, 5, 96, 66, 21, 9, 63, 20]
# (1) Criar Lista)
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) EstaOrdenada por ordem crescente
# (8) EstaOrdenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# A lista criada foi [1, 2, 3, 4]
# (1) Criar Lista)
# (2) Ler Lista
# (3) Soma
# (4) Média
# (5) Maior
# (6) Menor
# (7) EstaOrdenada por ordem crescente
# (8) EstaOrdenada por ordem decrescente
# (9) Procura um elemento
# (0) Sair
# A lista é a seguinte [1, 2, 3, 4]
# A soma da lista é  10
# ...
